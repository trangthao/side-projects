# %%
import requests
import pandas as pd
from urllib.parse import quote
from google.colab import drive

# Replace with your API key and CSE ID
API_KEY = 'AIzaSyBgmCEaaqGKOiNTO8dlaJPG3vj65uoSEEM'
CSE_ID = '3188519ef59574cdb'

def get_tax_id(firm_name):
    # Construct the search URL for the Google Custom Search API
    search_url = f"https://www.googleapis.com/customsearch/v1?q={quote(firm_name + ' mã số thuế')}&cx={CSE_ID}&key={API_KEY}"
    response = requests.get(search_url)
    results = response.json()

    # Check if any results are returned
    if 'items' in results:
        for item in results['items']:
            link = item['link']
            if 'masothue.com' in link:
                # Extract the tax ID directly from the link
                tax_id_match = re.search(r'/(\d{10})-', link)
                if tax_id_match:
                    return tax_id_match.group(1)
    return "NA"

def main():
    # Mount Google Drive
    drive.mount('/content/drive')

    # Read the list of firms from the .dta file
    df = pd.read_stata('/content/drive/MyDrive/projects/project4/data/processed/patents/applicant_new_vietnam_tomatch.dta')

    # Select specific rows (2406-2506)
    df_subset = df.iloc[23001:26000]

    # Assuming the firm names are in a column named 'TenDN_nor'
    firm_names = df_subset['TenDN_nor'].tolist()

    results = []
    for firm in firm_names:
        tax_id = get_tax_id(firm)
        results.append({"Firm Name": firm, "Tax ID": tax_id})
        print(f"{firm}: {tax_id}")

    # Convert results to DataFrame
    results_df = pd.DataFrame(results)

    # Save to CSV
    results_df.to_csv('/content/drive/MyDrive/projects/project4/data/processed/patents/firm_tax_ids12.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# SWISS SPA SYSTEM LTD.: NA
# SWISSMETAL UMS USINES METALLURGIQUES SUISSE SA: NA
# SXING DA INDUSTRIAL CO., LTD.: NA
# SYCOM INTERNATIONAL CORP.: NA
# SYH TECHNOLOGIES PTY LTD.: NA
# SYL VAN LEARNING SYSTEMS, INC: NA
# SYLENTIS S.A.U.: NA
# SYLENTIS SAU: NA
# SYMPHAR S.A.: NA
# SYMPHARS. A.: NA
# SYMPHOGEN A/S: NA
# SYMPHONY LIMITED: NA
# SYMPLANTA GMBH & CO KG: NA
# SYNCENTA PARTICIPATIONS AG: NA
# SYNCORE BIOTECHNOLOGY CO., LTD.: NA
# SYNDYNE INDUSTRIAL CO., LTD.: 3600256520
# SYNERON MEDICAL LTD.: NA
# SYNGAS SDN BHD: NA
# SYNGEN BIOTECH CO., LTD.: NA
# SYNGENTA CROP PROTECTION AG  : NA
# SYNGENTA KOREA LIMITED: 0305636093
# SYNGENTA LIMITED: 3600477110
# SYNGENTA LIMLTED: 3600477110
# SYNGENTA LIMTED: 3600477110
# SYNGENTA LLMITED: 3600477110
# SYNGENTA LLMLTED: 3600477110
# SYNGENTA PARTICIPATION AG: NA
# SYNGENTA PARTICIPATIONS (AG): 3600477110
# ...
